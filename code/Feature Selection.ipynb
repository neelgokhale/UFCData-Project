# %%
import os

from ufcdata.query import DatabaseQuery
from ufcdata.tools import query_to_df

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sb
import pickle as pkl

import warnings
warnings.filterwarnings('ignore')

# %%
ROOT_DIR = os.path.dirname(os.path.abspath("top_level_file.txt"))
DATA_DIR = os.path.join(ROOT_DIR, 'data')
DATA_PATH = os.path.join(DATA_DIR, 'data_1.pkl')

# %%
with open(DATA_PATH, 'rb') as f:
    df = pkl.load(f)

df
# Out:
#                fight_id        fighter_id               rd_id  rd  KO  SUB  \
# 0      e05a18b6ce22fa1f  52c2ae6d2f2d2613  e05a18b6ce22fa1f-1   1   0    0
# 1      e05a18b6ce22fa1f  da22387a0407a2dc  e05a18b6ce22fa1f-1   1   0    0
# 2      e05a18b6ce22fa1f  52c2ae6d2f2d2613  e05a18b6ce22fa1f-2   2   0    0
# 3      e05a18b6ce22fa1f  da22387a0407a2dc  e05a18b6ce22fa1f-2   2   0    0
# 4      e05a18b6ce22fa1f  52c2ae6d2f2d2613  e05a18b6ce22fa1f-3   3   0    0
# ...                 ...               ...                 ...  ..  ..  ...
# 21221  925a36a4af600291  5442f1bc4b47eaf3  925a36a4af600291-2   2   0    0
# 21222  925a36a4af600291  0a1942069c9ad6b6  925a36a4af600291-3   3   0    0
# 21223  925a36a4af600291  5442f1bc4b47eaf3  925a36a4af600291-3   3   0    0
# 21224  d0fb381cacbb0446  fa6796c55d6c5440  d0fb381cacbb0446-1   1   1    0
# 21225  d0fb381cacbb0446  399afbabc02376b5  d0fb381cacbb0446-1   1   0    0
#
#       weight_class_x  rd_won weight_class_y
# 0       Bantamweight     0.0   Bantamweight
# 1       Bantamweight     1.0   Bantamweight
# 2       Bantamweight     0.0   Bantamweight
# 3       Bantamweight     1.0   Bantamweight
# 4       Bantamweight     1.0   Bantamweight
# ...              ...     ...            ...
# 21221   Middleweight     0.0   Middleweight
# 21222   Middleweight     0.0   Middleweight
# 21223   Middleweight     1.0   Middleweight
# 21224    Heavyweight     0.0    Heavyweight
# 21225    Heavyweight     0.0    Heavyweight
#
# [21226 rows x 9 columns]
